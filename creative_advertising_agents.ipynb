# %% [markdown]
# # Creative Advertising Multi-Agent System
#
# **Assignment:** Week 2 — Part B
# **Framework:** OpenAI Agents SDK
# **Pipeline:** Creative Director → Strategist → Copywriter
#
# ---

# %%
# Section 1a — Install dependencies (run once)
# !pip install openai-agents python-dotenv nest_asyncio --quiet
# Out:
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Section 1b — Imports
import asyncio
import os
import nest_asyncio
from dotenv import load_dotenv
from agents import Agent, Runner

# Patch Jupyter's event loop so asyncio.run() works inside cells
nest_asyncio.apply()

print("Imports OK")
# Out:
# Imports OK

# %%
# Section 1c — Load API key from .env
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY not found. Copy .env.example to .env and add your key.")
print("API key loaded.")
# Out:
# API key loaded.

# %%
# Section 2 — Define the three agents

creative_director = Agent(
    name="Creative Director",
    model="gpt-4o-mini",
    instructions=(
        "You are a Creative Director at a top advertising agency. "
        "Given a product launch brief, generate 3 to 5 distinct campaign ideas. "
        "Format each idea with: **Name** (bold), *Tagline* (italic), "
        "and a 2-sentence description of the concept and target audience."
    ),
)

strategist = Agent(
    name="Strategist",
    model="gpt-4o-mini",
    instructions=(
        "You are a Marketing Strategist. You will receive a list of campaign ideas. "
        "Review them and select the top 2 ideas based on market potential, "
        "cultural fit, and originality. "
        "For each selected idea, explain in 2-3 sentences why it was chosen "
        "and what makes it commercially strong."
    ),
)

copywriter = Agent(
    name="Copywriter",
    model="gpt-4o-mini",
    instructions=(
        "You are a social media Copywriter. You will receive two selected campaign concepts. "
        "For each campaign, write exactly 3 tweets. "
        "Each tweet must: be under 280 characters, include 2-3 relevant hashtags, "
        "have an inspiring and eco-conscious tone, "
        "and feel native to the target location and audience."
    ),
)

print("Agents defined: Creative Director, Strategist, Copywriter")
# Out:
# Agents defined: Creative Director, Strategist, Copywriter

# %%
# Section 2 (cont.) — Pipeline function

async def run_pipeline(prompt: str):
    """Run the 3-agent campaign pipeline. Returns (ideas, strategy, tweets)."""
    cd_result = await Runner.run(creative_director, prompt)
    ideas = cd_result.final_output

    st_result = await Runner.run(strategist, ideas)
    strategy = st_result.final_output

    cw_result = await Runner.run(copywriter, strategy)
    tweets = cw_result.final_output

    return ideas, strategy, tweets

print("Pipeline function defined.")
# Out:
# Pipeline function defined.

# %%
# Section 3a — Step 1: Run Creative Director
TEST_PROMPT = "Launch a campaign for a new eco-friendly water bottle in Bali."

print("Running Creative Director...\n")
cd_result = asyncio.run(Runner.run(creative_director, TEST_PROMPT))
ideas = cd_result.final_output

print("=" * 60)
print("STEP 1: CREATIVE DIRECTOR — Campaign Ideas")
print("=" * 60)
print(ideas)
# Out:
# Running Creative Director...
#
# ============================================================
# STEP 1: CREATIVE DIRECTOR — Campaign Ideas
# ============================================================
# **1. Nature’s Gift**
# *“Sip Sustainably, Live Beautifully.”*
# This campaign focuses on the natural beauty of Bali and the importance of preserving it for future generations. The target audience is environmentally conscious travelers and locals who appreciate both aesthetics and sustainability, highlighting stunning landscapes paired with the water bottle’s eco-friendly benefits.
#
# **2. Bali Blue Revolution**
# *“Every Drop Counts.”*
# This concept features dynamic visuals of Bali’s pristine waters and wildlife, emphasizing the essential connection between hydration and environmental responsibility. Targeting eco-aware millennials and tourists, the campaign promotes the water bottle as a stylish accessory that supports clean oceans and responsible tourism.
#
# **3. Reflections of Bali**
# *“Drink in Harmony.”*
# This campaign showcases the water bottle’s reflective surface, visually mirroring the serene landscapes of Bali. Designed to resonate with yoga enthusiasts and wellness seekers, it invites users to embrace mindfulness and sustainability, encouraging a deeper connection to the environment with every sip.
#
# **4. The Green Wave**
# *“Ride the Change.”*
# A campaign that integrates local surf culture, featuring surfers and beachgoers using the eco-friendly bottle in their adventures. Targeting active and adventurous consumers, this idea underscores the message that each bottle helps combat ocean pollution, creating a community of responsible water sports enthusiasts.
#
# **5. Bali’s Heartbeat**
# *“Quench the Soul, Protect Our Home.”*
# This emotional campaign centers around the connection between the island's communities and their reliance on clean water sources, with personal stories from locals. Aiming at conscious consumers and socially responsible tourists, it positions the water bottle as not just a product but part of a larger movement towards preserving Bali's unique environment.
# [non-fatal] Tracing: server error 504, retrying.

# %%
# Section 3b — Step 2: Run Strategist
print("Running Strategist...\n")
st_result = asyncio.run(Runner.run(strategist, ideas))
strategy = st_result.final_output

print("=" * 60)
print("STEP 2: STRATEGIST — Top 2 Selections & Reasoning")
print("=" * 60)
print(strategy)
# Out:
# Running Strategist...
# [non-fatal] Tracing: server error 504, retrying.
# ============================================================
# STEP 2: STRATEGIST — Top 2 Selections & Reasoning
# ============================================================
# After evaluating the campaign ideas based on market potential, cultural fit, and originality, the top two selections are:
#
# ### 1. **Nature’s Gift**
# **Reason for Selection:** This campaign effectively combines the stunning natural beauty of Bali with a strong sustainability message, appealing to the growing market of environmentally conscious travelers. Its focus on aesthetics and eco-friendly benefits taps into a lucrative niche that values both style and environmental responsibility, making it commercially viable and culturally relevant.
#
# ### 2. **The Green Wave**
# **Reason for Selection:** By integrating local surf culture, this campaign targets an active demographic that is passionate about environmental issues, particularly ocean conservation. It leverages the community aspect of surf culture to foster a sense of belonging among consumers while reinforcing responsible water sports practices. This combination of lifestyle alignment and environmental advocacy positions it as an engaging and impactful campaign with strong market potential.

# %%
# Section 3c — Step 3: Run Copywriter
print("Running Copywriter...\n")
cw_result = asyncio.run(Runner.run(copywriter, strategy))
tweets = cw_result.final_output

print("=" * 60)
print("STEP 3: COPYWRITER — Tweets")
print("=" * 60)
print(tweets)
# Out:
# Running Copywriter...
#
# ============================================================
# STEP 3: COPYWRITER — Tweets
# ============================================================
# ### Campaign: Nature’s Gift
#
# **Tweet 1:** 🌿✨ Experience the magic of Bali—where every sunrise whispers sustainability! Let's honor nature’s beauty by traveling responsibly. Join us in protecting our paradise while exploring its wonders. 🌅 #NaturesGift #EcoTravel #SustainableBali
#
# **Tweet 2:** 🌺🏝️ Embrace the stunning landscapes of Bali while making a positive impact! Choose eco-friendly stays and activities to keep our island’s beauty alive for generations to come. 💚 #TravelGreen #BaliBeautiful #Sustainability
#
# **Tweet 3:** 🌄🌊 Nature is the ultimate gift! Let’s create memories in Bali that celebrate its breathtaking beauty while promoting eco-conscious choices. Together, we can leave only footprints! 🌍 #NatureLovers #EcoAdventure #BaliMagic
#
# ---
#
# ### Campaign: The Green Wave
#
# **Tweet 1:** 🌊🏄‍♂️ Ride the wave of change! Join our surf community in championing ocean conservation. Every wave we catch is a call to protect our waters. 🌊💙 #TheGreenWave #SurfForTheOcean #EcoWarriors
#
# **Tweet 2:** 🐬🌊 Let’s make every surf session count! With each ride, we can raise awareness about ocean health and encourage eco-friendly practices. Together, we can be stewards of our waves! 🌊💚 #OceanConscious #SustainableSurfing #ProtectOurSeas
#
# **Tweet 3:** 🌍🏄‍♀️ Surf’s up for sustainability! Dive into our local surf culture with a commitment to keeping our oceans clean. Together, let’s create a green future, one wave at a time! 🌊✨ #SurfGreen #OceanAdvocacy #CommunityImpact
# [non-fatal] Tracing: server error 504, retrying.
# [non-fatal] Tracing: max retries reached, giving up on this batch.
# [non-fatal] Tracing: server error 504, retrying.
# [non-fatal] Tracing: server error 504, retrying.
# [non-fatal] Tracing: server error 504, retrying.
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %% [markdown]
# ## Section 4 — Sample Output
#
# > Run all cells above (Kernel → Restart & Run All) to generate live output.
# > After running, the cell outputs above serve as the sample output for submission.
#
# *(The frozen cell outputs above are produced by the test prompt: "Launch a campaign for a new eco-friendly water bottle in Bali.")*

# %% [markdown]
# ## Section 5 — System Explanation
#
# ### Role of Each Agent
#
# | Agent | Role | Responsibility |
# |---|---|---|
# | **Creative Director** | Divergent thinker | Generates 3–5 distinct campaign ideas, each with a name, tagline, and 2-sentence description |
# | **Strategist** | Convergent thinker | Reviews all ideas and selects the top 2 based on market potential, cultural fit, and originality |
# | **Copywriter** | Executor | Translates each selected campaign into 3 ready-to-post tweets with hashtags |
#
# ### Tools and Functions Used
#
# - **`Agent(name, model, instructions)`** — Defines each agent's persona, the LLM model it runs on, and its task instructions. No tools or function calls are used — these are pure text-in/text-out agents.
# - **`Runner.run(agent, input)`** — Executes an agent asynchronously given an input string. Returns a `RunResult` object containing the agent's response.
# - **`result.final_output`** — A string attribute on `RunResult` that holds the agent's final text response. This string is passed directly as the input to the next agent in the pipeline.
# - **`nest_asyncio.apply()`** — Patches Python's running event loop so that `asyncio.run()` can be called from inside Jupyter notebook cells (which already have a running event loop).
# - **`python-dotenv` / `load_dotenv()`** — Loads environment variables from a `.env` file into `os.environ`, allowing the `OPENAI_API_KEY` to be set without hardcoding secrets in the notebook.
#
# ### Why a Multi-Agent Approach Improves the Workflow
#
# A single large prompt asking one LLM to generate ideas, evaluate them, and write tweets in one pass produces mediocre results — the model cannot switch creative modes mid-response without quality loss.
#
# The multi-agent pipeline improves on this in four concrete ways:
#
# 1. **Focused roles** — Each agent receives instructions optimized for exactly one task. The Creative Director is not constrained by commercial concerns; the Strategist is not biased toward ideas it generated itself.
# 2. **Real-team mirroring** — The Creative Director → Strategist → Copywriter sequence maps to how human advertising teams work. This makes the system's reasoning transparent and easy to audit.
# 3. **Inspectable intermediate outputs** — Each agent's output is a visible string before it enters the next stage. A human can read, edit, or redirect it between steps without restarting the pipeline.
# 4. **Modularity** — Any agent can be updated independently. Changing the Copywriter's tone (e.g., to LinkedIn format) requires editing only that agent's instructions, with no effect on the others.
